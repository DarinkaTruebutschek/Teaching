# %% [markdown]
# ### Recalling functions (exercise 4 in word doc)

# %%
# code here

# %% [markdown]
# What elements were you able to reproduce from memory? What did you struggle with? What elements do you recognise from the solution, what do you not recognise or understand how it works? How would you try and understand them?

# %% [markdown]
# ### Recalling bacics, loops and conditionals (exercise 5 in worddoc)
#
# We have a data structure that contains epochs, channels, time. Create a function that takes the data structure, and rejects an epoch if the absolute value exceeds the thresholds. Program it either using loops, or in a vectorised way.

# %% [markdown]
# #### Run this first to create a data-structure

# %%
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

# Create random EEG-like data
# Shape: (epochs, channels, timepoints)
data = np.random.normal(
    loc=0,
    scale=20,
    size=(10, 32, 500)
)

# Inject some artificial artefacts
# These epochs should be rejected
data[2, 10, 100] = 150
data[5, 3, 250] = -200
data[8, 20, 400] = 175

# Set rejection threshold
threshold = 100

print("Data shape:", data.shape)
print("Threshold:", threshold)

# %%
# Loop version

# %%
# vectorised version

# %% [markdown]
# What elements were you able to reproduce from memory? What did you struggle with? What elements do you recognise from the solution, what do you not recognise or understand how it works? How would you try and understand them?
#
# Insight questions:
#
# - Why use abs()?
# - What is the computational cost of the different approaches?
# - How would you speed up the loop version with parallel loops?

# %% [markdown]
# #### Recalling machine learning (exercise 6 in worddoc)
#
# Write code, can be pseudo-code wherever, that takes a pandas data frame with columns 12 columns of features, and a 13th column with labels. How would you structure your could to train and test a machine learning classifyer? You can structure it using pseudo-code, or real python code if you wish

# %%
# code here

# %% [markdown]
# Did you remember the general flow of a ML pipeline? What elements do you recognise from the solution? What have you forgotten?

# %% [markdown]
# #### Recalling statistics (exercise 7 in worddoc)
#
# Write (pseudo)-code that does a repeated measures anova, and returns the F-statistic and p-value. How would you structure your code?

# %%
# code here

# %% [markdown]
# What elements of the solution did you include? What did you forget?
#
# Insight questions:
# - What kind of variable is anova here?
# - How do you think .fit() knows what data to analyse?
